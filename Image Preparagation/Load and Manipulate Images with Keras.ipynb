# %% [markdown]
# ## 1. Test image

# %%
# Load image
from keras.utils import load_img
img = load_img("/home/tuandinh/Desktop/AI and Machine Learning/Deep Learninig/Image Preparagation/bondi_beach.jpg")
print(type(img))
print(img.format)
print(img.mode)
print(img.size)
img.show()
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>
# JPEG
# RGB
# (640, 427)

# %% [markdown]
# ### 2. Convert an Image With Keras
# + The load img() function provides additional arguments that may be useful when loading
# the image, such as ‘grayscale’ that allows the image to be loaded in grayscale (defaults to
# False),
# + and so on

# %%
from keras.utils import img_to_array
from keras.utils import array_to_img
img = load_img("/home/tuandinh/Desktop/AI and Machine Learning/Deep Learninig/Image Preparagation/bondi_beach.jpg")
print(type(img))
# convert to numpy array
img_array = img_to_array(img)
print(img_array.dtype)
print(img_array.shape)
# convert back to image
img_pil = array_to_img(img_array)
print(type(img))
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>
# float32
# (427, 640, 3)
# <class 'PIL.JpegImagePlugin.JpegImageFile'>

# %% [markdown]
# ### 3. Save image in keras

# %%
from keras.utils import save_img
import matplotlib.pyplot as plt

img_path = '/home/tuandinh/Desktop/AI and Machine Learning/Deep Learninig/Image Preparagation/bondi_beach.jpg'
img = load_img(img_path, color_mode='grayscale')
plt.imshow(img)
img_array = img_to_array(img) # need to convert to array to save img in keras
save_img('/home/tuandinh/Desktop/AI and Machine Learning/Deep Learninig/Image Preparagation/image_save/bondi_beach_grayscale.jpg', img_array)
