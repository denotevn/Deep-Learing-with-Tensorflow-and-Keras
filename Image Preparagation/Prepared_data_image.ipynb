# %%
# load and show an image with Pillow
from PIL import Image
# load the image
image = Image.open('/home/tuandinh/Desktop/AI and Machine Learning/Deep Learninig/CNN/image_cnn/convolutional_neural_network.png')
# summarize some details about the image
print(image.format)
print(image.mode)
print(image.size)
# show the imag
image.show()
# Out:
# PNG
# RGB
# (357, 741)

# %% [markdown]
# ## Convert images to Numpy arrays and back

# %%
# load and display image with matpplotlib
from matplotlib import image
from matplotlib import pyplot
# load image as pixel array
data = image.imread('/home/tuandinh/Desktop/AI and Machine Learning/Deep Learninig/CNN/image_cnn/convolutional_neural_network.png')
# summarize shape of the pixel array
print(data.dtype)
print(data.shape)
# display the array of pixels as an image
pyplot.imshow(data)
pyplot.show()
# Out:
# float32
# (741, 357, 3)

# %%
from PIL import Image
from numpy import asarray
#load image
image = Image.open('/home/tuandinh/Desktop/AI and Machine Learning/Deep Learninig/CNN/image_cnn/convolutional_neural_network.png')
# convert image tp numpy array
data = asarray(image)
print(data.shape)
# Create pillow image
image2 = Image.fromarray(data)
# summarize image details 
print(image2.format)
print(image2.mode)
print(image2.size)
# Out:
# (741, 357, 3)
# None
# RGB
# (357, 741)

# %%
# example of saving a grayscale version of a loaded image
from PIL import Image
# load the image
image = Image.open('/home/tuandinh/Desktop/AI and Machine Learning/Deep Learninig/Image Preparagation/Sydney-Opera-House_color.jpg')
# convert the image to grayscale
gs_image = image.convert(mode='L')
# save in jpeg format
gs_image.save('/home/tuandinh/Desktop/AI and Machine Learning/Deep Learninig/Image Preparagation/Sydney-Opera-House.jpg')
# load the image again and show it
image2 = Image.open('/home/tuandinh/Desktop/AI and Machine Learning/Deep Learninig/Image Preparagation/Sydney-Opera-House.jpg')
# show the imag
image2.show()

# %% [markdown]
# ## Flip, Rotate, and Crop Images

# %% [markdown]
# 1. Flip Image

# %%
# create flipped versions of an image
from PIL import Image
from matplotlib import pyplot
# load image
image = Image.open('/home/tuandinh/Desktop/AI and Machine Learning/Deep Learninig/Image Preparagation/Sydney-Opera-House_color.jpg')
# horizontal flip
hoz_flip = image.transpose(Image.FLIP_LEFT_RIGHT)
# vertical flip
ver_flip = image.transpose(Image.FLIP_TOP_BOTTOM)
# plot all three images using matplotlib
pyplot.subplot(311)
pyplot.imshow(image)
pyplot.subplot(312)
pyplot.imshow(hoz_flip)
pyplot.subplot(313)
pyplot.imshow(ver_flip)
# Out:
# /tmp/ipykernel_19512/1459077513.py:7: DeprecationWarning: FLIP_LEFT_RIGHT is deprecated and will be removed in Pillow 10 (2023-07-01). Use Transpose.FLIP_LEFT_RIGHT instead.
#   hoz_flip = image.transpose(Image.FLIP_LEFT_RIGHT)
# /tmp/ipykernel_19512/1459077513.py:9: DeprecationWarning: FLIP_TOP_BOTTOM is deprecated and will be removed in Pillow 10 (2023-07-01). Use Transpose.FLIP_TOP_BOTTOM instead.
#   ver_flip = image.transpose(Image.FLIP_TOP_BOTTOM)

# %% [markdown]
# 2. Rotate Image

# %%
# Create rotated version of an image
import matplotlib.pyplot as plt
from PIL import Image
from matplotlib import pyplot
# load image
image = Image.open('/home/tuandinh/Desktop/AI and Machine Learning/Deep Learninig/Image Preparagation/Sydney-Opera-House_color.jpg')
plt.subplot(311)
plt.imshow(image.rotate(45))
plt.subplot(313)
plt.imshow(image.rotate(90))
plt.show()

# %% [markdown]
# 3. Crop Image

# %%
# example of cropping an image
from PIL import Image
# load image
image = Image.open('/home/tuandinh/Desktop/AI and Machine Learning/Deep Learninig/Image Preparagation/Sydney-Opera-House_color.jpg')
# create a cropped image
cropped = image.crop((100, 100, 200, 200))
# show cropped image
plt.imshow(cropped)
