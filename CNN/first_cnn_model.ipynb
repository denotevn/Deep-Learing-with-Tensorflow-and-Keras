# %%
from keras.utils import plot_model
from keras.models import Model
from keras.layers import Input
from keras.layers import Dense, Flatten
from keras.layers import Conv2D, MaxPooling2D

visible = Input(shape=(64,64,1))
conv1 = Conv2D(32, (4,4), activation='relu')(visible)
pool1 = MaxPooling2D()(conv1)
conv2 = Conv2D(16, (4,4), activation='relu')(pool1)
pool2 = MaxPooling2D()(conv2)
flat1 = Flatten()(pool2)
hidden1 = Dense(10, activation='relu')(flat1)
output = Dense(1, activation='sigmoid')(hidden1)

model = Model(inputs=visible, outputs=output)

# summarize layers
model.summary()

plot_model(model, to_file='/home/tuandinh/Desktop/AI and Machine Learning/Deep Learninig/CNN/image_cnn/convolutional_neural_network.png')
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_3 (InputLayer)        [(None, 64, 64, 1)]       0
#
#  conv2d_4 (Conv2D)           (None, 61, 61, 32)        544
#
#  max_pooling2d_4 (MaxPooling  (None, 30, 30, 32)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 27, 27, 16)        8208
#
#  max_pooling2d_5 (MaxPooling  (None, 13, 13, 16)       0
#  2D)
#
#  flatten_2 (Flatten)         (None, 2704)              0
#
#  dense_4 (Dense)             (None, 10)                27050
#
#  dense_5 (Dense)             (None, 1)                 11
#
# ...
# Total params: 35,813
# Trainable params: 35,813
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Recurrent Neural Network

# %%
from keras.utils import plot_model
from keras.models import Model
from keras.layers import Input, Dense
from keras.layers import LSTM

visible = Input(shape=(100,1))
hidden1 = LSTM(10)(visible)

hidden2 = Dense(10, activation='relu')(hidden1)
output = Dense(1, activation='sigmoid')(hidden2)
model = Model(inputs=visible, outputs=output)
# summarize layers
model.summary()
# plot graph
plot_model(model, to_file='/home/tuandinh/Desktop/AI and Machine Learning/Deep Learninig/CNN/image_cnn/recurrent_neural_network.png')
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_4 (InputLayer)        [(None, 100, 1)]          0
#
#  lstm (LSTM)                 (None, 10)                480
#
#  dense_6 (Dense)             (None, 10)                110
#
#  dense_7 (Dense)             (None, 1)                 11
#
# ...
# Total params: 601
# Trainable params: 601
# Non-trainable params: 0
# _________________________________________________________________
